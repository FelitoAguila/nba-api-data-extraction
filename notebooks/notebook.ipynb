# %% [markdown]
# ### Testing api endpoint results

# %%
from nba_api.stats.endpoints import playercareerstats

# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id=203076)
AD_df = career.get_data_frames()[0]

print(AD_df.columns.tolist())
# Out:
# ['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']

# %%
from nba_api.stats.static import players
import pandas as pd

# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print(f"Number of players fetched: {len(nba_players)}")

nba_players_df = pd.DataFrame(nba_players)
# Out:
# Number of players fetched: 5103

# %%
tyrese_maxey = nba_players_df[nba_players_df['full_name'] == 'Tyrese Maxey']

# Maxey Career Stats
career = playercareerstats.PlayerCareerStats(player_id=tyrese_maxey['id'].iloc[0])
maxey_career_df = career.get_data_frames()[0]

# %%
maxey_career_df
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1630178   2020-21        00  1610612755               PHI        20.0
# 1    1630178   2021-22        00  1610612755               PHI        21.0
# 2    1630178   2022-23        00  1610612755               PHI        22.0
# 3    1630178   2023-24        00  1610612755               PHI        23.0
# 4    1630178   2024-25        00  1610612755               PHI        24.0
# 5    1630178   2025-26        00  1610612755               PHI        25.0
#
#    GP  GS   MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  61   8   936  198  ...   0.871    11    93  104  120   26   13   41   79
# 1  75  74  2650  483  ...   0.866    26   214  240  321   55   32   88  156
# 2  60  41  2016  439  ...   0.845    23   153  176  212   49    8   80  132
# 3  70  70  2626  638  ...   0.868    36   222  258  433   69   33  116  151
# ...

# %% [markdown]
# ### Testing reading parquet files

# %%
import pyarrow.parquet as pq

nba_teams_table = pq.read_table("../data/nba_teams.parquet")
parquet_file = pq.ParquetFile("../data/nba_teams.parquet")

nba_players_table = pq.read_table("../data/nba_players.parquet")

# %%
parquet_file.metadata
# Out:
# ...
#   created_by: parquet-cpp-arrow version 25.0.0
#   num_columns: 7
#   num_rows: 30
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1494

# %%
print(nba_teams_table.shape)
# print(nba_teams_table.column_names)
# print(nba_teams_table.nbytes)
# print(nba_teams_table.num_columns)
# print(nba_teams_table.num_rows)
print(nba_teams_table.schema)

nba_teams_table
# Out:
# (30, 7)
# id: int64
# full_name: string
# abbreviation: string
# nickname: string
# city: string
# state: string
# year_founded: int64
# pyarrow.Table
# id: int64
# full_name: string
# abbreviation: string
# nickname: string
# city: string
# state: string
# year_founded: int64
# ----
# id: [[1610612737,1610612738,1610612739,1610612740,1610612741,...,1610612762,1610612763,1610612764,1610612765,1610612766]]
# full_name: [["Atlanta Hawks","Boston Celtics","Cleveland Cavaliers","New Orleans Pelicans","Chicago Bulls",...,"Utah Jazz","Memphis Grizzlies","Washington Wizards","Detroit Pistons","Charlotte Hornets"]]
# abbreviation: [["ATL","BOS","CLE","NOP","CHI",...,"UTA","MEM","WAS","DET","CHA"]]
# nickname: [["Hawks","Celtics","Cavaliers","Pelicans","Bulls",...,"Jazz","Grizzlies","Wizards","Pistons","Hornets"]]
# city: [["Atlanta","Boston","Cleveland","New Orleans","Chicago",...,"Utah","Memphis","Washington","Detroit","Charlotte"]]
# ...

# %%
print(nba_players_table.shape)
print(nba_players_table.schema)

nba_players_table
# Out:
# (5103, 5)
# id: int64
# full_name: string
# first_name: string
# last_name: string
# is_active: bool
# pyarrow.Table
# id: int64
# full_name: string
# first_name: string
# last_name: string
# is_active: bool
# ----
# id: [[76001,76002,76003,51,1505,...,78650,1641783,1628427,1642365,203967]]
# full_name: [["Alaa Abdelnaby","Zaid Abdul-Aziz","Kareem Abdul-Jabbar","Mahmoud Abdul-Rauf","Tariq Abdul-Wahad",...,"Matt Zunic","Tristan da Silva","Vlatko Čančar","Nikola Đurišić","Dario Šarić"]]
# first_name: [["Alaa","Zaid","Kareem","Mahmoud","Tariq",...,"Matt","Tristan","Vlatko","Nikola","Dario"]]
# last_name: [["Abdelnaby","Abdul-Aziz","Abdul-Jabbar","Abdul-Rauf","Abdul-Wahad",...,"Zunic","da Silva","Čančar","Đurišić","Šarić"]]
# is_active: [[false,false,false,false,false,...,false,true,false,true,true]]

# %%
nba_players_career = pq.read_table("../data/player_career_stats_by_season.parquet")

# %%
print(nba_players_career.shape)
print(nba_players_career.schema)
# Out:
# (30899, 28)
# PLAYER_ID: int64
# SEASON_ID: large_string
# LEAGUE_ID: large_string
# TEAM_ID: int64
# TEAM_ABBREVIATION: large_string
# PLAYER_AGE: double
# GP: int64
# GS: double
# MIN: double
# FGM: int64
# FGA: int64
# FG_PCT: double
# FG3M: double
# FG3A: double
# FG3_PCT: double
# FTM: int64
# FTA: int64
# FT_PCT: double
# OREB: double
# DREB: double
# REB: double
# AST: int64
# STL: double
# BLK: double
# TOV: double
# PF: int64
# PTS: int64
# player_name: large_string
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 3153

# %%
df_players = nba_players_career.to_pandas()

# %%
df_players.nunique()
# Out:
# PLAYER_ID            4855
# SEASON_ID              80
# LEAGUE_ID               1
# TEAM_ID                46
# TEAM_ABBREVIATION      75
# PLAYER_AGE             34
# GP                     88
# GS                     84
# MIN                  3337
# FGM                   907
# FGA                  1726
# FG_PCT                593
# FG3M                  282
# FG3A                  645
# FG3_PCT               430
# FTM                   656
# FTA                   807
# FT_PCT                664
# OREB                  385
# DREB                  784
# REB                  1160
# AST                   797
# STL                   240
# BLK                   285
# TOV                   347
# PF                    359
# PTS                  2150
# player_name          4821
# dtype: int64
